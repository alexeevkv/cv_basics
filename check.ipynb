# %%
import torch
import albumentations as A
import matplotlib.pyplot as plt

from src.torch.dataset import data_split
from src.config import prepare_config

# %%
dataset_params = prepare_config('./params.yaml', config_key='dataset', resolve=True)['cifar10']

train_dataloader, val_dataloader, test_dataloader = data_split(**dataset_params)

# %%
image = train_dataloader.dataset[1][0]

# %%
plt.imshow(image)

# %%
tr = prepare_config('./params.yaml', config_key='augmentation', resolve=True)['train']
# Out:
# /home/kv.alekseev/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/augmentations/transforms.py:1149: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/kv.alekseev/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/imgaug/transforms.py:231: FutureWarning: IAASharpen is deprecated. Please use Sharpen instead
#   warnings.warn("IAASharpen is deprecated. Please use Sharpen instead", FutureWarning)
# /home/kv.alekseev/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/augmentations/transforms.py:1175: FutureWarning: RandomContrast has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].imshow(image.transpose(1, 2, 0).astype(int))
ax[1].imshow(tr(image=image.transpose(1, 2, 0))['image'].astype(int))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 fig, ax = plt.subplots(nrows=1, ncols=2)
#       2 ax[0].imshow(image.transpose(1, 2, 0).astype(int))
# ----> 3 ax[1].imshow(tr(image=image.transpose(1, 2, 0))['image'].astype(int))
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/core/composition.py:205, in Compose.__call__(self, force_apply, *args, **data)
#     202     p.preprocess(data)
#     204 for idx, t in enumerate(transforms):
# --> 205     data = t(**data)
#     207     if check_each_transform:
#     208         data = self._check_data_post_transform(data)
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/core/composition.py:309, in OneOf.__call__(self, force_apply, *args, **data)
#     307     idx: int = random_utils.choice(len(self.transforms), p=self.transforms_ps)
#     308     t = self.transforms[idx]
# --> 309     data = t(force_apply=True, **data)
#     310 return data
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/core/transforms_interface.py:118, in BasicTransform.__call__(self, force_apply, *args, **kwargs)
#     113             warn(
#     114                 self.get_class_fullname() + " could work incorrectly in ReplayMode for other input data"
#     115                 " because its' params depend on targets."
#     116             )
#     117         kwargs[self.save_key][id(self)] = deepcopy(params)
# --> 118     return self.apply_with_params(params, **kwargs)
#     120 return kwargs
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/core/transforms_interface.py:131, in BasicTransform.apply_with_params(self, params, **kwargs)
#     129     target_function = self._get_target_function(key)
#     130     target_dependencies = {k: kwargs[k] for k in self.target_dependence.get(key, [])}
# --> 131     res[key] = target_function(arg, **dict(params, **target_dependencies))
#     132 else:
#     133     res[key] = None
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/augmentations/transforms.py:1310, in CLAHE.apply(self, img, clip_limit, **params)
#    1307 if not is_rgb_image(img) and not is_grayscale_image(img):
#    1308     raise TypeError("CLAHE transformation expects 1-channel or 3-channel images.")
# -> 1310 return F.clahe(img, clip_limit, self.tile_grid_size)
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/augmentations/utils.py:122, in preserve_channel_dim.<locals>.wrapped_function(img, *args, **kwargs)
#     119 @wraps(func)
#     120 def wrapped_function(img: np.ndarray, *args: P.args, **kwargs: P.kwargs) -> np.ndarray:
#     121     shape = img.shape
# --> 122     result = func(img, *args, **kwargs)
#     123     if len(shape) == 3 and shape[-1] == 1 and len(result.shape) == 2:
#     124         result = np.expand_dims(result, axis=-1)
#
# File ~/projects/cv_basics/venv/lib/python3.9/site-packages/albumentations/augmentations/functional.py:452, in clahe(img, clip_limit, tile_grid_size)
#     449 @preserve_channel_dim
#     450 def clahe(img, clip_limit=2.0, tile_grid_size=(8, 8)):
#     451     if img.dtype != np.uint8:
# --> 452         raise TypeError("clahe supports only uint8 inputs")
#     454     clahe_mat = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
#     456     if len(img.shape) == 2 or img.shape[2] == 1:
#
# TypeError: clahe supports only uint8 inputs
