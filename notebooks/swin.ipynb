# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# TODO 
# Посмотреть что такое ignite

# %%
import torch
import torch.nn.functional as F
from torch import nn

from src.config import prepare_config
from src.visualize.utils import vis_batch
from src.collections.models.swin import SwinTransformer

# %%
random_batch = torch.rand((10, 3, 32, 32))

# %%
vis_batch(random_batch, [i + 1 for i in range(len(random_batch))])

# %% [markdown]
# # Swin

# %%
net_conf = '../conf/model/swin.yaml'

# %%
net = prepare_config(net_conf, resolve=True)['net']
