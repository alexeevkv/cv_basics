# %%
import mlflow
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../')

from src.utils.diploma_utils import plot_metrics
from src.utils.mapping import EXPERIMENT_TO_MLFLOW_INFO

# %%
for experiment_name, meta_info in EXPERIMENT_TO_MLFLOW_INFO.items():
    print("---------------------------------------------")
    print(f"Графики для эксперимента: {experiment_name}")
    plot_metrics(**meta_info)
    print()
# Out:
# ---------------------------------------------
# Графики для эксперимента: ResNet_no_augm_adam
# ---------------------------------------------
# Графики для эксперимента: ResNet_no_augm_adamw
# ---------------------------------------------
# Графики для эксперимента: Swin_no_augm_adamw
